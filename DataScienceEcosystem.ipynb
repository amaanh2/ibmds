# %% [markdown]
# ***Analysis of House Prices Based on Features***

# %% [markdown]
# *Amaan Ahmed, 100874313*

# %% [markdown]
# *I selected a dataset centered on house prices, covering a diverse set of house features such as square footage, bedrooms, bathrooms, neighborhood types, and construction year. I found this dataset on Kaggle at https://www.kaggle.com/datasets/muhammadbinimran/housing-price-prediction-data/data. The major question I was thinking of while looking at this dataset was: "How does a house's attributes, such as size, bedroom count, and neighborhood type, impact its market price, and what insights can be obtained from examining these relationships through data science methodologies?" To answer this question, I created a variety of graphs, including scatter plots, line graphs, bar graphs, box plots, and histograms, to visually represent the connections between specific factors. I chose this dataset due my interest in real estate, a field I aspire to do as a side hustle in the future. This project not only provided a great learning experience in data analysis but also offered gerat insights into the patterns shaping housing prices and strategies for making good investments. Through this exploration, I've gained valuable knowledge applicable not only to academic pursuits but also as a foundation for informed decision making in the world of real estate.*

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = "https://raw.githubusercontent.com/amaan135/Assignment/main/housing_price_dataset.csv"
df = pd.read_csv(data)

df = df.dropna()
df = df.drop_duplicates()

df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065

# %% [markdown]
# *I have imported all the necessary libraries needed for this project. Loaded the data from a public url into "data" and used pandas to read the CSV file into "df". And cleaned the dataset by removing any rows with missing values and removing an duplicate values. Displayed the head to make sure the data has been loaded correctly.*

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='SquareFeet', y='Price', data=df)
plt.title('Square Feet vs. Price')
plt.xlabel('Square Feet')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# *This scatter plot shows the relation between the size of the house in square feet and price of the house. As you can see in the graph, as the size of the house increases, the price also increases. This is true for majority of houses across the dataset. for example, according to the dataset. there is a 1000 sq ft house which is more expensive than a 3000 sq ft house. This can be due to factors such as neighborhood or year built, as we will see in the upcoming analysis.*

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(x='YearBuilt', y='Price', hue='Neighborhood', data=df)
plt.title('Price Difference Between Rural, Urban, and Suburban Neighborhoods Over the Years')
plt.xlabel('Year Built')
plt.ylabel('Price')
plt.legend(title='Neighborhood', loc='upper left')
plt.show()

# %% [markdown]
# *This line graph shows the change in average house price each year in different types of neighborhoods over the last 70 years. There has been a lot of fluctuation in price over the years. It seems that urban neighborhoods tend to keep the highest price and look to be the best investment. On the other hand, suburbs seems to be mostly within the bottom to mid range, while rural started off all over the place but seems to be more consistent recently. Based off the current graph, If I had to make a prediction, I would say all house prices would increase over the next couple of years before they drop.*

# %%
average_price_by_bedrooms = df.groupby('Bedrooms')['Price'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='Bedrooms', y='Price', data=average_price_by_bedrooms, palette='viridis')
plt.title('Relationship Between Bedrooms and Price')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Average Price')
plt.show()

# %% [markdown]
# *This bar graph shows the relation of bedrooms to average house price. There is no doubt that the more rooms a house has, the more expensive it will be. Out of 50,000 houses compared in 3 different types of neighborhoods, the minimum bedrooms a house must have is 2 bedrooms and the maximumm is 5 bedrooms. Based off the graph of square footage to price, and this one, we can say that the bigger the house, the more rooms it will have.*

# %%
average_price_by_bathrooms = df.groupby('Bathrooms')['Price'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='Bathrooms', y='Price', data=average_price_by_bathrooms, palette='plasma')
plt.title('Relationship Between Bathrooms and Price')
plt.xlabel('Number of Bathrooms')
plt.ylabel('Average Price')
plt.show()

# %% [markdown]
# *This bar graph shows the relation of bedrooms to average house price. Once again, the more bathrooms a house has, the more expensive it will be. The minimum bathrooms a house must have is 1 bathroom and the maximum is 3 bathrooms. Based off the graph of square footage to price, bedroom vs price, and this one, we can say that the bigger the house, the more bathrooms it will have.*

# %%
# Create a boxplot to show the size of houses across different neighborhoods
plt.figure(figsize=(12, 8))
sns.boxplot(x='Neighborhood', y='SquareFeet', data=df, palette='Set3')
plt.title('Size of Houses Across Different Neighborhoods')
plt.xlabel('Neighborhood')
plt.ylabel('Square Feet')
plt.show()
#urban largest, rural, suburb

# %% [markdown]
# *This boxplot shows the sizes of houses across different neighborhoods. This boxplot shows us that urban neighborhoods, on average, have bigger house than rural (second) and suburb neighborhoods. This makes sense considering the neighborhood vs price graph from earlier. Urban houses are larger on average which is why they are more expensive.*

# %%
# Create a histogram to show the distribution of housing prices
plt.figure(figsize=(10, 6))
sns.histplot(df['Price'], bins=20, kde=True, color='green', edgecolor='black')
plt.title('Distribution of Housing Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# *This historigram shows the frequency of houses in each price range. There are 50,000 houses in this dataset. More than 6000 of those are around the price of $200,000. This shows that the average population lives in house worth $200,000. The top 10% of wealthy home owners own a house that is atleast $400,000. If we consider the neighborhood vs price graph, we can assume that most of the top 10% wealthy live in urban neighborhoods.*
